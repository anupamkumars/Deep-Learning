# %% [markdown]
# # Sigmoid

# %%
import math

def sigmoid(x):
  return 1 / (1 + math.exp(-1))

# %%
sigmoid(100)
# Out:
# 0.7310585786300049

# %%
sigmoid(1)
# Out:
# 0.7310585786300049

# %%
sigmoid(-56)
# Out:
# 0.7310585786300049

# %%
sigmoid(0.5)
# Out:
# 0.7310585786300049

# %% [markdown]
# # tanh

# %%
def tanh(x):
  return (math.exp(x) - math.exp(-x)) / (math.exp(x) + math.exp(-x))

# %%
tanh(-56)
# Out:
# -1.0

# %%
tanh(50)
# Out:
# 1.0

# %%
tanh(1)
# Out:
# 0.7615941559557649

# %% [markdown]
# # ReLU

# %%
def relu(x):
  return max(0,x)

# %%
relu(-7)
# Out:
# 0

# %%
relu(1)
# Out:
# 1

# %%
relu(6)
# Out:
# 6

# %%
relu(8)
# Out:
# 8

# %%
relu(-100)
# Out:
# 0

# %% [markdown]
# # Leaky ReLU

# %%
def leaky_relu(x):
  return max(0.1*x,x)

# %%
leaky_relu(-100)
# Out:
# -10.0

# %%
leaky_relu(8)
# Out:
# 8
